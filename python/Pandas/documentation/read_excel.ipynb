# %%
# Importando a biblioteca pandas 
import pandas as pd

# %%
# Abrindo e fazendo a leitura de uma arquivo excel 
# por padrão ele abre sempre a primeira aba do arquivo excel 
df=pd.read_excel('Dados.xlsx', sheet_name='Aba1')
df
# Out:
#      BusinessEntityID PersonType  NameStyle Title  FirstName MiddleName  \
# 0                   1         EM          0   NaN        Ken          J
# 1                   2         EM          0   NaN      Terri        Lee
# 2                   3         EM          0   NaN    Roberto        NaN
# 3                   4         EM          0   NaN        Rob        NaN
# 4                   5         EM          0   Ms.       Gail          A
# ..                ...        ...        ...   ...        ...        ...
# 995              1700         IN          0   Ms.    Rebecca         A.
# 996              1701         IN          0   Ms.    Dorothy         B.
# 997              1702         IN          0   Ms.  Carol Ann         F.
# 998              1703         IN          0   Mr.      Scott         M.
# 999              1704         IN          0   Mr.        Jim        NaN
#
#        LastName Suffix  EmailPromotion
# 0       Sánchez    NaN               0
# ...

# %%
# Abrindo a segunda aba do arquivo excel 
df=pd.read_excel('Dados.xlsx',sheet_name='Aba2')
df
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM          0   NaN       Ken          J
# 1                 2         EM          0   NaN     Terri        Lee
# 2                 3         EM          0   NaN   Roberto        NaN
# 3                 4         EM          0   NaN       Rob        NaN
# 4                 5         EM          0   Ms.      Gail          A
# 5                 6         EM          0   Mr.    Jossef          H
# 6                 7         EM          0   NaN     Dylan          A
# 7                 8         EM          0   NaN     Diane          L
#
#      LastName  Suffix  EmailPromotion
# 0     Sánchez     NaN               0
# 1       Duffy     NaN               1
# 2  Tamburello     NaN               0
# 3     Walters     NaN               0
# 4    Erickson     NaN               0
# 5    Goldberg     NaN               0
# 6      Miller     NaN               2
# ...

# %%
# Verificando a Existência do Arquivo Excel
arquivo_excel=pd.ExcelFile('Dados.xlsx')
# Verificando o nome das Abas que tenho no arquivo Excel 
arquivo_excel.sheet_names
# Usando o método parse para selecionar o conteúdo das abaas 
ab1=arquivo_excel.parse('Aba1')
ab2=arquivo_excel.parse('Aba2')
ab1.tail()
# Out:
#      BusinessEntityID PersonType  NameStyle Title  FirstName MiddleName  \
# 995              1700         IN          0   Ms.    Rebecca         A.
# 996              1701         IN          0   Ms.    Dorothy         B.
# 997              1702         IN          0   Ms.  Carol Ann         F.
# 998              1703         IN          0   Mr.      Scott         M.
# 999              1704         IN          0   Mr.        Jim        NaN
#
#      LastName Suffix  EmailPromotion
# 995  Robinson    NaN               0
# 996  Robinson    NaN               2
# 997    Rockne    NaN               0
# 998   Rodgers    NaN               0
# 999    Rodman    NaN               0

# %%
ab2.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM          0   NaN       Ken          J
# 1                 2         EM          0   NaN     Terri        Lee
# 2                 3         EM          0   NaN   Roberto        NaN
# 3                 4         EM          0   NaN       Rob        NaN
# 4                 5         EM          0   Ms.      Gail          A
#
#      LastName  Suffix  EmailPromotion
# 0     Sánchez     NaN               0
# 1       Duffy     NaN               1
# 2  Tamburello     NaN               0
# 3     Walters     NaN               0
# 4    Erickson     NaN               0
